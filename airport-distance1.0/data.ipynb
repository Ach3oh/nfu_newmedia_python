# %%
import csv
with open('airport-codes.csv') as csvfile:
     reader = csv.DictReader(csvfile)     
     for row in reader:
         print(row['ident'], row['coordinates'])
# Out:
# 00A 40.07080078, -74.93360138
# 00AK 59.94919968, -151.6959991
# 00AL 34.8647995, -86.77030182
# 00AR 35.6086998, -91.25489807
# 00AZ 34.30559921, -112.1650009
# 00CA 35.3504982, -116.8880005
# 00CO 40.62220001, -104.3440018
# 00FA 28.64550018, -82.21900177
# 00FD 28.84659958, -82.34539795
# 00FL 27.23089981, -80.96920013
# 00GA 33.76750183, -84.06829834
# 00GE 33.88420105, -84.73390198
# 00HI 19.83250046, -155.9819946
# 00ID 48.14530182, -116.2139969
# 00II 41.64450073, -87.12280273
# 00IL 41.97840118, -89.56040192
# 00IN 41.51139832, -87.26059723
# 00IS 40.02560043, -89.12290192
# 00KS 38.72779846, -94.93049622
# 00KY 37.40940094, -84.61969757
# 00LA 30.191944, -90.980833
# 00LL 39.66529846, -89.70559692
# 00LS 30.13629913, -92.42939758
# 00MD 38.75709915, -75.75379944
# 00MI 43.94940186, -86.41670227
# 00MN 46.29999924, -95.70030212
# 00MO 37.20280075, -94.41239929
# 00MT 48.53749847, -109.7050018
# 00N 39.47320175, -75.18520355
# 00NC 36.08520126, -78.37139893
# ...

# %%
import csv

with open('airport-codes.csv') as data:
    #ignore = data.readline()          #  no need if using  csv.DictReader 
    airport_data = {}
    for line in csv.reader(data):  #  no need if using  csv.DictReader
        print(line)
# Out:
# ['ident', 'type', 'name', 'coordinates', 'elevation_ft', 'continent', 'iso_country', 'iso_region', 'municipality', 'gps_code', 'iata_code', 'local_code']
# ['00A', 'heliport', 'Total Rf Heliport', '40.07080078, -74.93360138', '11', 'NA', 'US', 'US-PA', 'Bensalem', '00A', '', '00A']
# ['00AK', 'small_airport', 'Lowell Field', '59.94919968, -151.6959991', '450', 'NA', 'US', 'US-AK', 'Anchor Point', '00AK', '', '00AK']
# ['00AL', 'small_airport', 'Epps Airpark', '34.8647995, -86.77030182', '820', 'NA', 'US', 'US-AL', 'Harvest', '00AL', '', '00AL']
# ['00AR', 'heliport', 'Newport Hospital & Clinic Heliport', '35.6086998, -91.25489807', '237', 'NA', 'US', 'US-AR', 'Newport', '00AR', '', '00AR']
# ['00AZ', 'small_airport', 'Cordes Airport', '34.30559921, -112.1650009', '3810', 'NA', 'US', 'US-AZ', 'Cordes', '00AZ', '', '00AZ']
# ['00CA', 'small_airport', 'Goldstone /Gts/ Airport', '35.3504982, -116.8880005', '3038', 'NA', 'US', 'US-CA', 'Barstow', '00CA', '', '00CA']
# ...
